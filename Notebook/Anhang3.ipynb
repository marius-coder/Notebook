# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#UBA-2030" data-toc-modified-id="UBA-2030-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>UBA-2030</a></span><ul class="toc-item"><li><span><a href="#Last_mit_Glätt" data-toc-modified-id="Last_mit_Glätt-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Last_mit_Glätt</a></span></li><li><span><a href="#Last_mit_Komp" data-toc-modified-id="Last_mit_Komp-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Last_mit_Komp</a></span></li><li><span><a href="#Last_mit_Komp_mit_Glätt" data-toc-modified-id="Last_mit_Komp_mit_Glätt-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Last_mit_Komp_mit_Glätt</a></span></li></ul></li><li><span><a href="#UBA-2050" data-toc-modified-id="UBA-2050-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>UBA-2050</a></span><ul class="toc-item"><li><span><a href="#Last_mit_Glätt" data-toc-modified-id="Last_mit_Glätt-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Last_mit_Glätt</a></span></li><li><span><a href="#Last_mit_Komp" data-toc-modified-id="Last_mit_Komp-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Last_mit_Komp</a></span></li><li><span><a href="#Last_mit_Komp_mit_Glätt" data-toc-modified-id="Last_mit_Komp_mit_Glätt-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Last_mit_Komp_mit_Glätt</a></span></li></ul></li><li><span><a href="#GPC-2030" data-toc-modified-id="GPC-2030-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>GPC-2030</a></span><ul class="toc-item"><li><span><a href="#Last_mit_Glätt" data-toc-modified-id="Last_mit_Glätt-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Last_mit_Glätt</a></span></li><li><span><a href="#Last_mit_Komp" data-toc-modified-id="Last_mit_Komp-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Last_mit_Komp</a></span></li><li><span><a href="#Last_mit_Komp_mit_Glätt" data-toc-modified-id="Last_mit_Komp_mit_Glätt-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Last_mit_Komp_mit_Glätt</a></span></li></ul></li><li><span><a href="#GPC-2050" data-toc-modified-id="GPC-2050-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>GPC-2050</a></span><ul class="toc-item"><li><span><a href="#Last_mit_Glätt" data-toc-modified-id="Last_mit_Glätt-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Last_mit_Glätt</a></span></li><li><span><a href="#Last_mit_Komp" data-toc-modified-id="Last_mit_Komp-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Last_mit_Komp</a></span></li><li><span><a href="#Last_mit_Komp_mit_Glätt" data-toc-modified-id="Last_mit_Komp_mit_Glätt-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Last_mit_Komp_mit_Glätt</a></span></li></ul></li><li><span><a href="#IGW-2030" data-toc-modified-id="IGW-2030-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>IGW-2030</a></span><ul class="toc-item"><li><span><a href="#Last_mit_Glätt" data-toc-modified-id="Last_mit_Glätt-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Last_mit_Glätt</a></span></li><li><span><a href="#Last_mit_Komp" data-toc-modified-id="Last_mit_Komp-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Last_mit_Komp</a></span></li><li><span><a href="#Last_mit_Komp_mit_Glätt" data-toc-modified-id="Last_mit_Komp_mit_Glätt-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Last_mit_Komp_mit_Glätt</a></span></li></ul></li><li><span><a href="#FHT-2050" data-toc-modified-id="FHT-2050-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>FHT-2050</a></span><ul class="toc-item"><li><span><a href="#Last_mit_Glätt" data-toc-modified-id="Last_mit_Glätt-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Last_mit_Glätt</a></span></li><li><span><a href="#Last_mit_Komp" data-toc-modified-id="Last_mit_Komp-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Last_mit_Komp</a></span></li><li><span><a href="#Last_mit_Komp_mit_Glätt" data-toc-modified-id="Last_mit_Komp_mit_Glätt-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Last_mit_Komp_mit_Glätt</a></span></li></ul></li><li><span><a href="#Vergelich-REslat-zwischen-Var" data-toc-modified-id="Vergelich-REslat-zwischen-Var-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Vergelich REslat zwischen Var</a></span></li><li><span><a href="#Strommix" data-toc-modified-id="Strommix-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Strommix</a></span></li><li><span><a href="#Vergleich-Speicherbewirtschaftung" data-toc-modified-id="Vergleich-Speicherbewirtschaftung-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Vergleich Speicherbewirtschaftung</a></span></li><li><span><a href="#Vergelich-CO2-Emissioenen" data-toc-modified-id="Vergelich-CO2-Emissioenen-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Vergelich CO2 Emissioenen</a></span></li><li><span><a href="#Vergleich-2050" data-toc-modified-id="Vergleich-2050-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Vergleich 2050</a></span><ul class="toc-item"><li><span><a href="#Vergelich-REslat-zwischen-Var" data-toc-modified-id="Vergelich-REslat-zwischen-Var-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Vergelich REslat zwischen Var</a></span></li><li><span><a href="#Strommix" data-toc-modified-id="Strommix-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Strommix</a></span></li><li><span><a href="#Vergleich-Speicherbewirtschaftung" data-toc-modified-id="Vergleich-Speicherbewirtschaftung-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Vergleich Speicherbewirtschaftung</a></span></li><li><span><a href="#Vergelich-CO2-Emissioenen" data-toc-modified-id="Vergelich-CO2-Emissioenen-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Vergelich CO2 Emissioenen</a></span></li></ul></li></ul></div>

# %%
from datetime import datetime 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timezone
plt.rcParams.update({'figure.max_open_warning': 0})
from matplotlib.ticker import FormatStrFormatter
#from scipy.signal import savgol_filtergrid

from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from gekko import GEKKO

var = "consumption"
#var = "production"
import matplotlib
import locale
# Set to German locale to get comma decimal separater
locale.setlocale(locale.LC_NUMERIC, "deu_deu")

dti_2030 = pd.date_range('2030-01-01', periods=8760, freq='H')
dti_2050 = pd.date_range('2050-01-01', periods=8760, freq='H')

# %%
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ")
print("There is currently no clean way to add the weeknumber since index.week is deprecated")
print("This function creates them with a loop and the funciton isocalendar")
print("Name: CreateWeekNum ")
print("Input: df_Source ")
print("Output: list of weeknumbers")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ")
def CreateWeekNum(df_Source):
    li_weeknum = []
    for rows in range(0,len(df_Source),1):
        li_weeknum.append(df_Source.index[rows].isocalendar()[1])
    return li_weeknum

# %%
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ")
print("Little helper function to add various time related columns to dataframes")
print("Name: DataFrameTimeIndexing ")
print("Input: df_Source ")
print("Output: added columns to DataFrame")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ")
def DataFrameTimeIndexing(dfSource):
    dfSource['year'] = dfSource.index.year
    dfSource['quarter'] = dfSource.index.quarter
    dfSource['month'] = dfSource.index.month
    dfSource['week'] = CreateWeekNum(dfSource)
    dfSource['date'] = dfSource.index.day
    dfSource['hour'] = dfSource.index.hour
    return

# %% [markdown]
# # UBA-2030

# %%
df_UBA_2030_Bericht = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_BERICHT.csv"
                     ,delimiter = ';')
df_UBA_2030_Bericht = df_UBA_2030_Bericht.set_index(dti_2030)
DataFrameTimeIndexing(df_UBA_2030_Bericht)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df_UBA_2030_Alte = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_Ohne_Komp.csv"
                     ,delimiter = ';')
df_UBA_2030_Alte = df_UBA_2030_Alte.set_index(dti_2030)
DataFrameTimeIndexing(df_UBA_2030_Alte)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_20 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_20 = Last_mit_Komp_mit_Glätt_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_40 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_40 = Last_mit_Komp_mit_Glätt_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_60 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_60 = Last_mit_Komp_mit_Glätt_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_80 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_80 = Last_mit_Komp_mit_Glätt_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_100 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_100 = Last_mit_Komp_mit_Glätt_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_20 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_20 = Last_mit_Glätt_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_40 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_40 = Last_mit_Glätt_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_60 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_60 = Last_mit_Glätt_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_80 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_80 = Last_mit_Glätt_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_100 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_100 = Last_mit_Glätt_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_20 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_20 = Last_mit_Komp_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_40 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_40 = Last_mit_Komp_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_60 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_60 = Last_mit_Komp_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_80 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_80 = Last_mit_Komp_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_100 = pd.read_csv("../Data/2030/UBA/Szen_UBA-2030_Last_mit_Komp_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_100 = Last_mit_Komp_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_100)

# %% [markdown]
# ## Last_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_UBA_2030_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_UBA_2030_Alte["PSP"].sum() -  df_UBA_2030_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Glätt_20["PSP"].sum()-  Last_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Glätt_40["PSP"].sum()-  Last_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Glätt_60["PSP"].sum()-  Last_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Glätt_80["PSP"].sum()-  Last_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Glätt_100["PSP"].sum()-  Last_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Speicherenergie", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen UBA/Vergleich_Erzeugte_Energie_Speicher_Glättung", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_UBA_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_UBA_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(35,40)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen UBA/CO2_Emissionen_Glättung", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_UBA_2030_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_UBA_2030_Alte["PSP"].sum() -  df_UBA_2030_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_20["PSP"].sum()-  Last_mit_Komp_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_40["PSP"].sum()-  Last_mit_Komp_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_60["PSP"].sum()-  Last_mit_Komp_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_80["PSP"].sum()-  Last_mit_Komp_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_100["PSP"].sum()-  Last_mit_Komp_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen UBA/Vergleich_Erzeugte_Energie_Kompensation", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_UBA_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_UBA_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,45)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen UBA/CO2_Emissionen_Kompensation", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((Last_mit_Glätt_40["PSP"].sum() -  Last_mit_Glätt_40["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_mit_Glätt_20["PSP"].sum()-  Last_mit_Komp_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_mit_Glätt_40["PSP"].sum()-  Last_mit_Komp_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_mit_Glätt_60["PSP"].sum()-  Last_mit_Komp_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_mit_Glätt_80["PSP"].sum()-  Last_mit_Komp_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_mit_Glätt_100["PSP"].sum()-  Last_mit_Komp_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen UBA/Vergleich_Erzeugte_Energie_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_UBA_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,40)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen UBA/CO2_Emissionen_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # UBA-2050

# %%
df_UBA_2050_Bericht = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_BERICHT.csv"
                     ,delimiter = ';')
df_UBA_2050_Bericht = df_UBA_2050_Bericht.set_index(dti_2050)
DataFrameTimeIndexing(df_UBA_2050_Bericht)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df_UBA_2050_Alte = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_Ohne_Komp.csv"
                     ,delimiter = ';')
df_UBA_2050_Alte = df_UBA_2050_Alte.set_index(dti_2050)
DataFrameTimeIndexing(df_UBA_2050_Alte)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_20 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_20 = Last_mit_Komp_mit_Glätt_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_40 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_40 = Last_mit_Komp_mit_Glätt_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_60 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_60 = Last_mit_Komp_mit_Glätt_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_80 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_80 = Last_mit_Komp_mit_Glätt_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_100 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_100 = Last_mit_Komp_mit_Glätt_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_20 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_20 = Last_mit_Glätt_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_40 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_40 = Last_mit_Glätt_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_60 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_60 = Last_mit_Glätt_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_80 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_80 = Last_mit_Glätt_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_100 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_100 = Last_mit_Glätt_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_20 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_20 = Last_mit_Komp_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_40 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_40 = Last_mit_Komp_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_60 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_60 = Last_mit_Komp_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_80 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_80 = Last_mit_Komp_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_100 = pd.read_csv("../Data/2050/UBA/Szen_UBA-2050_Last_mit_Komp_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_100 = Last_mit_Komp_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_100)

# %% [markdown]
# ## Last_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_UBA_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_UBA_2050_Alte["PSP"].sum() -  df_UBA_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Glätt_20["PSP"].sum()-  Last_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Glätt_40["PSP"].sum()-  Last_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Glätt_60["PSP"].sum()-  Last_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Glätt_80["PSP"].sum()-  Last_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Glätt_100["PSP"].sum()-  Last_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Speicherenergie", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos)
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen UBA/Vergleich_Erzeugte_Energie_Speicher_Glättung", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_UBA_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_UBA_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,35)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen UBA/CO2_Emissionen_Glättung", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_UBA_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_UBA_2050_Alte["PSP"].sum() -  df_UBA_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_20["PSP"].sum()-  Last_mit_Komp_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_40["PSP"].sum()-  Last_mit_Komp_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_60["PSP"].sum()-  Last_mit_Komp_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_80["PSP"].sum()-  Last_mit_Komp_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_100["PSP"].sum()-  Last_mit_Komp_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen UBA/Vergleich_Erzeugte_Energie_Kompensation", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_UBA_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_UBA_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,35)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen UBA/CO2_Emissionen_Kompensation", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((Last_mit_Glätt_40["PSP"].sum() -  Last_mit_Glätt_40["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_mit_Glätt_20["PSP"].sum()-  Last_mit_Komp_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_mit_Glätt_40["PSP"].sum()-  Last_mit_Komp_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_mit_Glätt_60["PSP"].sum()-  Last_mit_Komp_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_mit_Glätt_80["PSP"].sum()-  Last_mit_Komp_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_mit_Glätt_100["PSP"].sum()-  Last_mit_Komp_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen UBA/Vergleich_Erzeugte_Energie_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_UBA_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,35)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen UBA/CO2_Emissionen_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # GPC-2030

# %%
df_GPC_2030_Bericht = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_BERICHT.csv"
                     ,delimiter = ';')
df_GPC_2030_Bericht = df_GPC_2030_Bericht.set_index(dti_2030)
DataFrameTimeIndexing(df_GPC_2030_Bericht)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df_GPC_2030_Alte = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_Ohne_Komp.csv"
                     ,delimiter = ';')
df_GPC_2030_Alte = df_GPC_2030_Alte.set_index(dti_2030)
DataFrameTimeIndexing(df_GPC_2030_Alte)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_20 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_20 = Last_mit_Komp_mit_Glätt_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_40 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_40 = Last_mit_Komp_mit_Glätt_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_60 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_60 = Last_mit_Komp_mit_Glätt_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_80 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_80 = Last_mit_Komp_mit_Glätt_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_100 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_100 = Last_mit_Komp_mit_Glätt_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_20 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_20 = Last_mit_Glätt_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_40 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_40 = Last_mit_Glätt_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_60 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_60 = Last_mit_Glätt_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_80 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_80 = Last_mit_Glätt_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_100 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_100 = Last_mit_Glätt_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_20 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_20 = Last_mit_Komp_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_40 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_40 = Last_mit_Komp_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_60 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_60 = Last_mit_Komp_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_80 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_80 = Last_mit_Komp_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_100 = pd.read_csv("../Data/2030/GPC/Szen_GPC-2030_Last_mit_Komp_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_100 = Last_mit_Komp_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_100)

# %% [markdown]
# ## Last_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_GPC_2030_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_GPC_2030_Alte["PSP"].sum() -  df_GPC_2030_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Glätt_20["PSP"].sum()-  Last_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Glätt_40["PSP"].sum()-  Last_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Glätt_60["PSP"].sum()-  Last_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Glätt_80["PSP"].sum()-  Last_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Glätt_100["PSP"].sum()-  Last_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen GPC/Vergleich_Erzeugte_Energie_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_GPC_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_GPC_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(40,80)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen GPC/CO2_Emissionen_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_GPC_2030_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_GPC_2030_Alte["PSP"].sum() -  df_GPC_2030_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_20["PSP"].sum()-  Last_mit_Komp_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_40["PSP"].sum()-  Last_mit_Komp_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_60["PSP"].sum()-  Last_mit_Komp_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_80["PSP"].sum()-  Last_mit_Komp_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_100["PSP"].sum()-  Last_mit_Komp_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen GPC/Vergleich_Erzeugte_Energie_komp", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_GPC_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_GPC_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
#ax[1].set_ylim(60,70)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen GPC/CO2_Emissionen_KOmp", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((Last_mit_Glätt_40["PSP"].sum() -  Last_mit_Glätt_40["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_mit_Glätt_20["PSP"].sum()-  Last_mit_Komp_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_mit_Glätt_40["PSP"].sum()-  Last_mit_Komp_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_mit_Glätt_60["PSP"].sum()-  Last_mit_Komp_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_mit_Glätt_80["PSP"].sum()-  Last_mit_Komp_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_mit_Glätt_100["PSP"].sum()-  Last_mit_Komp_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen GPC/Vergleich_Erzeugte_Energie_Komp_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
#ax[1].set_ylim(40,50)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen GPC/CO2_Emissionen_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # GPC-2050

# %%
df_GPC_2050_Bericht = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_BERICHT.csv"
                     ,delimiter = ';')
df_GPC_2050_Bericht = df_GPC_2050_Bericht.set_index(dti_2050)
DataFrameTimeIndexing(df_GPC_2050_Bericht)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df_GPC_2050_Alte = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_Ohne_Komp.csv"
                     ,delimiter = ';')
df_GPC_2050_Alte = df_GPC_2050_Alte.set_index(dti_2050)
DataFrameTimeIndexing(df_GPC_2050_Alte)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_20 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_20 = Last_mit_Komp_mit_Glätt_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_40 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_40 = Last_mit_Komp_mit_Glätt_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_60 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_60 = Last_mit_Komp_mit_Glätt_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_80 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_80 = Last_mit_Komp_mit_Glätt_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_100 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_100 = Last_mit_Komp_mit_Glätt_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_20 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_20 = Last_mit_Glätt_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_40 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_40 = Last_mit_Glätt_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_60 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_60 = Last_mit_Glätt_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_80 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_80 = Last_mit_Glätt_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_100 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_100 = Last_mit_Glätt_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_20 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_20 = Last_mit_Komp_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_40 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_40 = Last_mit_Komp_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_60 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_60 = Last_mit_Komp_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_80 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_80 = Last_mit_Komp_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_100 = pd.read_csv("../Data/2050/GPC/Szen_GPC-2050_Last_mit_Komp_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_100 = Last_mit_Komp_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_100)

# %% [markdown]
# ## Last_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_GPC_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_GPC_2050_Alte["PSP"].sum() -  df_GPC_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Glätt_20["PSP"].sum()-  Last_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Glätt_40["PSP"].sum()-  Last_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Glätt_60["PSP"].sum()-  Last_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Glätt_80["PSP"].sum()-  Last_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Glätt_100["PSP"].sum()-  Last_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen GPC/Vergleich_Erzeugte_Energie_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_GPC_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_GPC_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(33,38)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen GPC/CO2_Emissionen_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_GPC_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_GPC_2050_Alte["PSP"].sum() -  df_GPC_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_20["PSP"].sum()-  Last_mit_Komp_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_40["PSP"].sum()-  Last_mit_Komp_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_60["PSP"].sum()-  Last_mit_Komp_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_80["PSP"].sum()-  Last_mit_Komp_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_100["PSP"].sum()-  Last_mit_Komp_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen GPC/Vergleich_Erzeugte_Energie_komp", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_GPC_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_GPC_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(33,38)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen GPC/CO2_Emissionen_KOmp", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((Last_mit_Glätt_40["PSP"].sum() -  Last_mit_Glätt_40["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_mit_Glätt_20["PSP"].sum()-  Last_mit_Komp_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_mit_Glätt_40["PSP"].sum()-  Last_mit_Komp_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_mit_Glätt_60["PSP"].sum()-  Last_mit_Komp_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_mit_Glätt_80["PSP"].sum()-  Last_mit_Komp_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_mit_Glätt_100["PSP"].sum()-  Last_mit_Komp_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen GPC/Vergleich_Erzeugte_Energie_Komp_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(33,38)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen GPC/CO2_Emissionen_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # IGW-2030

# %%
df_IGW_2030_Bericht = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_BERICHT.csv"
                     ,delimiter = ';')
df_IGW_2030_Bericht = df_IGW_2030_Bericht.set_index(dti_2030)
DataFrameTimeIndexing(df_IGW_2030_Bericht)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df_IGW_2030_Alte = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_Ohne_Komp.csv"
                     ,delimiter = ';')
df_IGW_2030_Alte = df_IGW_2030_Alte.set_index(dti_2030)
DataFrameTimeIndexing(df_IGW_2030_Alte)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_20 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_20 = Last_mit_Komp_mit_Glätt_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_40 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_40 = Last_mit_Komp_mit_Glätt_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_60 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_60 = Last_mit_Komp_mit_Glätt_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_80 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_80 = Last_mit_Komp_mit_Glätt_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_100 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_100 = Last_mit_Komp_mit_Glätt_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_20 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_20 = Last_mit_Glätt_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_40 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_40 = Last_mit_Glätt_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_60 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_60 = Last_mit_Glätt_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_80 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_80 = Last_mit_Glätt_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_100 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_100 = Last_mit_Glätt_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_20 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_20 = Last_mit_Komp_20.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_40 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_40 = Last_mit_Komp_40.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_60 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_60 = Last_mit_Komp_60.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_80 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_80 = Last_mit_Komp_80.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_100 = pd.read_csv("../Data/2030/IGW/Szen_IGW-2030_Last_mit_Komp_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_100 = Last_mit_Komp_100.set_index(dti_2030)
DataFrameTimeIndexing(Last_mit_Komp_100)

# %% [markdown]
# ## Last_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_IGW_2030_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_IGW_2030_Alte["PSP"].sum() -  df_IGW_2030_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Glätt_20["PSP"].sum()-  Last_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Glätt_40["PSP"].sum()-  Last_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Glätt_60["PSP"].sum()-  Last_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Glätt_80["PSP"].sum()-  Last_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Glätt_100["PSP"].sum()-  Last_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen IGW/Vergleich_Erzeugte_Energie_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_IGW_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_IGW_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
#ax[1].set_ylim(75,85)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen IGW/CO2_Emissionen_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_IGW_2030_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_IGW_2030_Alte["PSP"].sum() -  df_IGW_2030_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_20["PSP"].sum()-  Last_mit_Komp_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_40["PSP"].sum()-  Last_mit_Komp_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_60["PSP"].sum()-  Last_mit_Komp_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_80["PSP"].sum()-  Last_mit_Komp_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_100["PSP"].sum()-  Last_mit_Komp_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen IGW/Vergleich_Erzeugte_Energie_komp", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_IGW_2030_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_IGW_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(70,80)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen IGW/CO2_Emissionen_KOmp", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((Last_mit_Glätt_40["PSP"].sum() -  Last_mit_Glätt_40["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_mit_Glätt_20["PSP"].sum()-  Last_mit_Komp_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_mit_Glätt_40["PSP"].sum()-  Last_mit_Komp_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_mit_Glätt_60["PSP"].sum()-  Last_mit_Komp_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_mit_Glätt_80["PSP"].sum()-  Last_mit_Komp_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_mit_Glätt_100["PSP"].sum()-  Last_mit_Komp_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2030/Szen IGW/Vergleich_Erzeugte_Energie_Komp_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(70,75)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Szen IGW/CO2_Emissionen_Komp_und_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # FHT-2050

# %%
df_FHT_2050_Bericht = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_BERICHT.csv"
                     ,delimiter = ';')
df_FHT_2050_Bericht = df_FHT_2050_Bericht.set_index(dti_2050)
DataFrameTimeIndexing(df_FHT_2050_Bericht)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df_FHT_2050_Alte = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_Ohne_Komp.csv"
                     ,delimiter = ';')
df_FHT_2050_Alte = df_FHT_2050_Alte.set_index(dti_2050)
DataFrameTimeIndexing(df_FHT_2050_Alte)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_20 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_20 = Last_mit_Komp_mit_Glätt_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_40 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_40 = Last_mit_Komp_mit_Glätt_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_60 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_60 = Last_mit_Komp_mit_Glätt_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_80 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_80 = Last_mit_Komp_mit_Glätt_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_mit_Glätt_100 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_mit_Glätt_100 = Last_mit_Komp_mit_Glätt_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_20 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Glätt_20%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_20 = Last_mit_Glätt_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_40 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Glätt_40%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_40 = Last_mit_Glätt_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_60 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Glätt_60%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_60 = Last_mit_Glätt_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_80 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Glätt_80%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_80 = Last_mit_Glätt_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Glätt_100 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Glätt_100%.csv"
                     ,delimiter = ';')
Last_mit_Glätt_100 = Last_mit_Glätt_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Glätt_100)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_20 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_20%.csv"
                     ,delimiter = ';')
Last_mit_Komp_20 = Last_mit_Komp_20.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_20)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_40 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_40%.csv"
                     ,delimiter = ';')
Last_mit_Komp_40 = Last_mit_Komp_40.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_40)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_60 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_60%.csv"
                     ,delimiter = ';')
Last_mit_Komp_60 = Last_mit_Komp_60.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_60)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_80 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_80%.csv"
                     ,delimiter = ';')
Last_mit_Komp_80 = Last_mit_Komp_80.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_80)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Last_mit_Komp_100 = pd.read_csv("../Data/2050/FHT/Szen_FHT-2050_Last_mit_Komp_100%.csv"
                     ,delimiter = ';')
Last_mit_Komp_100 = Last_mit_Komp_100.set_index(dti_2050)
DataFrameTimeIndexing(Last_mit_Komp_100)

# %% [markdown]
# ## Last_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario FHT_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_FHT_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_FHT_2050_Alte["PSP"].sum() -  df_FHT_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Glätt_20["PSP"].sum()-  Last_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Glätt_40["PSP"].sum()-  Last_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Glätt_60["PSP"].sum()-  Last_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Glätt_80["PSP"].sum()-  Last_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Glätt_100["PSP"].sum()-  Last_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen FHT/Vergleich_Erzeugte_Energie_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_FHT_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario FHT_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_FHT_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,35)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Glättung",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen FHT/CO2_Emissionen_Glätt", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario FHT_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_FHT_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_FHT_2050_Alte["PSP"].sum() -  df_FHT_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_20["PSP"].sum()-  Last_mit_Komp_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_40["PSP"].sum()-  Last_mit_Komp_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_60["PSP"].sum()-  Last_mit_Komp_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_80["PSP"].sum()-  Last_mit_Komp_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_100["PSP"].sum()-  Last_mit_Komp_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen FHT/Vergleich_Erzeugte_Energie_Komp", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_FHT_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario FHT_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_FHT_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(30,35)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen FHT/CO2_Emissionen_Komp", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Last_mit_Komp_mit_Glätt

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 5))

li_Color = ["grey","blue","cyan","green","orange","red"]

li_Legend = ["Szenario FHT_2050","Szenario GPC_2050","Szenario IGW_2050"]
df_To_Plot = pd.DataFrame()

df_To_Plot["H2_Alt"] = pd.Series(df_FHT_2050_Alte["H2"].sum() / 1e6)
df_To_Plot["H2_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["H2"].sum() / 1e6)
df_To_Plot["H2_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["H2"].sum() / 1e6)
df_To_Plot["H2_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["H2"].sum() / 1e6)
df_To_Plot["H2_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["H2"].sum() / 1e6)
df_To_Plot["H2_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["H2"].sum() / 1e6)
df_To_Plot.plot(kind = "bar", ax = ax[2], color = li_Color, zorder = 3, legend = False)

ax[2].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[2].set_title("Methanspeicher", fontsize = 16);
ax[2].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[2].yaxis.grid(True)

df_To_Plot2 = pd.DataFrame()
df_To_Plot2["PSP_Alt"] = pd.Series((df_FHT_2050_Alte["PSP"].sum() -  df_FHT_2050_Alte["li_H2"].sum())/ 1e6)
df_To_Plot2["PSP_20"] = pd.Series((Last_mit_Komp_mit_Glätt_20["PSP"].sum()-  Last_mit_Komp_mit_Glätt_20["li_H2"].sum() )/ 1e6)
df_To_Plot2["PSP_40"] = pd.Series((Last_mit_Komp_mit_Glätt_40["PSP"].sum()-  Last_mit_Komp_mit_Glätt_40["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_60"] = pd.Series((Last_mit_Komp_mit_Glätt_60["PSP"].sum()-  Last_mit_Komp_mit_Glätt_60["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_80"] = pd.Series((Last_mit_Komp_mit_Glätt_80["PSP"].sum()-  Last_mit_Komp_mit_Glätt_80["li_H2"].sum()) / 1e6)
df_To_Plot2["PSP_100"] = pd.Series((Last_mit_Komp_mit_Glätt_100["PSP"].sum()-  Last_mit_Komp_mit_Glätt_100["li_H2"].sum()) / 1e6)
df_To_Plot2.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)
ax[1].set_title("Wasserspeicher", fontsize = 16);
ax[1].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[1].yaxis.grid(True)
ax[1].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
                                 
df_To_Plot3 = pd.DataFrame()                             
df_To_Plot3["Sum_Alt"] = df_To_Plot["H2_Alt"] + df_To_Plot2["PSP_Alt"]
df_To_Plot3["Sum_20"] = df_To_Plot["H2_20"] + df_To_Plot2["PSP_20"]
df_To_Plot3["Sum_40"] = df_To_Plot["H2_40"] + df_To_Plot2["PSP_40"]
df_To_Plot3["Sum_60"] = df_To_Plot["H2_60"] + df_To_Plot2["PSP_60"]
df_To_Plot3["Sum_80"] = df_To_Plot["H2_80"] + df_To_Plot2["PSP_80"]
df_To_Plot3["Sum_100"] = df_To_Plot["H2_100"] + df_To_Plot2["PSP_100"]
df_To_Plot3.plot(kind = "bar", ax = ax[0], color = li_Color, zorder = 3, legend = False)

ax[0].set_ylabel("Leistung [TWh]", fontsize = 14);
ax[0].set_title("Speicher Gesamt", fontsize = 16);
ax[0].tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False) 
ax[0].yaxis.grid(True)                                 
                                 

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                           , loc="upper center", bbox_to_anchor=(0.54,0.92), ncol = 6,
                facecolor='#f5f5f5', framealpha=1)
fig.suptitle("Vergleich der erzeugten Energien", fontsize=20)
pos = ax[0].get_position()
pos.y1 = 1.065   #height
ax[0].set_position(pos) 
plt.tight_layout()
plt.savefig("../Bilder/2050/Szen FHT/Vergleich_Erzeugte_Energie_Glätt_Komp", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["black","blue","cyan","green","orange","red"]



df_To_Plot = pd.DataFrame()

df_To_Plot["CO2_Intensity_Alt"] = df_FHT_2050_Alte["CO2_Intensity"]
df_To_Plot["CO2_Intensity_20"] = Last_mit_Komp_mit_Glätt_20["CO2_Intensity"]
df_To_Plot["CO2_Intensity_40"] = Last_mit_Komp_mit_Glätt_40["CO2_Intensity"]
df_To_Plot["CO2_Intensity_60"] = Last_mit_Komp_mit_Glätt_60["CO2_Intensity"]
df_To_Plot["CO2_Intensity_80"] = Last_mit_Komp_mit_Glätt_80["CO2_Intensity"]
df_To_Plot["CO2_Intensity_100"] = Last_mit_Komp_mit_Glätt_100["CO2_Intensity"]

df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color, legend = False)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);


ax[0].yaxis.grid(True)


li_Legend = ["Szenario FHT_2050","Szenario GPC_2050","Szenario IGW_2050"]

df_To_Plot = pd.DataFrame()
df_To_Plot["CO2_Intensity_Alt"] =pd.Series(df_FHT_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_20"] = pd.Series(Last_mit_Komp_mit_Glätt_20["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_40"] = pd.Series(Last_mit_Komp_mit_Glätt_40["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_60"] = pd.Series(Last_mit_Komp_mit_Glätt_60["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_80"] = pd.Series(Last_mit_Komp_mit_Glätt_80["CO2_Intensity"].mean())
df_To_Plot["CO2_Intensity_100"] = pd.Series(Last_mit_Komp_mit_Glätt_100["CO2_Intensity"].mean())


df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])
ax[1].set_ylim(28,33)
fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20, y = 1.02)

leg = fig.legend(title = "Kompensation",title_fontsize = 12, labels = ["0%","20%","40%","60%","80%","100%",],fontsize = 12
                 , ncol = 6, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.5,0.965))
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

pos = ax[0].get_position()
pos.y1 = 1.02   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Szen FHT/CO2_Emissionen_Glätt_Komp", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # Vergelich REslat zwischen Var

# %%
fig, ax = plt.subplots(figsize=(12, 5))
li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
df_UBA_2030_Bericht["Residuallast"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "red" )
#df_UBA_2030_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="red", marker='.', alpha=0.08, linestyle='None', legend=False)


df_GPC_2030_Bericht["Residuallast"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "blue" )
#df_GPC_2030_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="blue", marker='.', alpha=0.08, linestyle='None', legend=False)

df_IGW_2030_Bericht["Residuallast"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "green" )
#df_IGW_2030_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="green", marker='.', alpha=0.08, linestyle='None', legend=False)

ax.set_xlabel("")
ax.set_ylabel("Residuallast [MW]", fontsize = 13)
ax.set_title("Residuallast der Szenarien für 2030 ohne reaktive Energieträger", fontsize = 20)
ax.set_xticklabels(li_Months)
plt.setp(ax.get_xticklabels(), fontsize=13)
plt.setp(ax.get_yticklabels(), fontsize=13)


leg = fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.91), labels = ["UBA","GPC","IGW"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

ax.yaxis.grid(True)


plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Residuallast_2030", bbox_inches = 'tight',pad_inches = 0.08)

# %%
  
    
fig, ax = plt.subplots(figsize=(6,4))

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_UBA"] = df_UBA_2030_Bericht["Residuallast"].sort_values(ascending = False)




sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_UBA",ax = ax, color = "red")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_GPC"] = df_GPC_2030_Bericht["Residuallast"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_GPC",ax = ax, color = "blue")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_IGW"] = df_IGW_2030_Bericht["Residuallast"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_IGW",ax = ax, color = "green")



ax.set_title("Leistungskennlinie der Residuallast\nohne reaktive Energieträger",fontsize = 16)
ax.set_xlabel("Stunde", fontsize = 14)
ax.set_ylabel("Leistung [MW]", fontsize = 14)
ax.yaxis.grid(True)

leg = fig.legend(loc="upper center", bbox_to_anchor=(0.6,0.835), labels = ["UBA","GPC","IGW"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
    
plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Residuallast_Leistungskennlinie_2030", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(12, 5))
li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
df_UBA_2030_Alte["Residuallast_H2"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "red" )
#df_UBA_2030_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="red", marker='.', alpha=0.08, linestyle='None', legend=False)


df_GPC_2030_Alte["Residuallast_H2"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "blue" )
#df_GPC_2030_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="blue", marker='.', alpha=0.08, linestyle='None', legend=False)

df_IGW_2030_Alte["Residuallast_H2"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "green" )
#df_IGW_2030_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="green", marker='.', alpha=0.08, linestyle='None', legend=False)

ax.set_xlabel("")
ax.set_ylabel("Residuallast [MW]", fontsize = 13)
ax.set_title("Residuallast der Szenarien für 2030 mit Wasser- und Methanspeicher", fontsize = 20)
ax.set_xticklabels(li_Months)
plt.setp(ax.get_xticklabels(), fontsize=13)
plt.setp(ax.get_yticklabels(), fontsize=13)


leg = fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.91), labels = ["UBA","GPC","IGW"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

ax.yaxis.grid(True)


plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Residuallast_2030_mit_reaktiv", bbox_inches = 'tight',pad_inches = 0.08)

# %%
  
    
fig, ax = plt.subplots(figsize=(6,4))

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_H2_UBA"] = df_UBA_2030_Alte["Residuallast_H2"].sort_values(ascending = False)




sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_H2_UBA",ax = ax, color = "red")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_H2_GPC"] = df_GPC_2030_Alte["Residuallast_H2"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_H2_GPC",ax = ax, color = "blue")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_H2_IGW"] = df_IGW_2030_Alte["Residuallast_H2"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_H2_IGW",ax = ax, color = "green")



ax.set_title("Leistungskennlinie der Residuallast\nmit Speicher",fontsize = 16)
ax.set_xlabel("Stunde", fontsize = 14)
ax.set_ylabel("Leistung [MW]", fontsize = 14)
ax.yaxis.grid(True)

leg = fig.legend(loc="upper center", bbox_to_anchor=(0.6,0.835), labels = ["UBA","GPC","IGW"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
    
plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Residuallast_Leistungskennlinie_mit_reaktiv", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # Strommix

# %%
li_To_Plot = ["Biomasse","Hydro","Solar","Wind","Geot","Gas","PSP","H2","Import"]
li_labels = ["Biomasse","Wasserkraft","Photovoltaik","Windkraft","Geothermie","Gas","Wasserspeicher","Methanspeicher","Import"]
fig, ax = plt.subplots(figsize=(4,7))
colors_UBA = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_GPC = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_IGW = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
df_To_Plot = pd.DataFrame()

df_To_Plot2 = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_UBA_2030_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
df_To_Plot.insert(0,"index",0)
    
df_To_Plot[li_To_Plot].plot(kind = "bar", stacked = True, ax = ax,legend = False,position = 6,width=0.05, color = colors_UBA )

df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_GPC_2030_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
    

df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False, position=0,width=0.05, color = colors_GPC)


df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_IGW_2030_Alte[li_To_Plot[i]].sum() / 1e6)

 
df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False,position=3,width=0.05, color = colors_IGW)
ax.set_ylabel("Energie [TWh]")
ax.set_ylim(0,100)
leg = fig.legend(loc="upper center", bbox_to_anchor=(1.25,0.898), labels = li_labels, ncol = 1
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
plt.figtext(0.305,0.76, "UBA",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.52,0.835, "IGW",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.74,0.73, "GPC",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
fig.suptitle('Produzierte Energie der Szenarien\naufgeteilt auf Energieträger', fontsize=20, x = 0.8)

plt.tick_params(axis='x', which='both',bottom=False,top=False, labelbottom=False) 
pos = ax.get_position()
pos.y1 = 0.96   #height
ax.set_position(pos)
plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Produzierte Energie", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # Vergleich Speicherbewirtschaftung

# %%
df_PSP_Storage = pd.read_csv("../Data/Water Reservoirs and Hydro Storage Plants_201812310000-201912300000.csv"
                     ,delimiter = ',')
#df_PSP_Storage.iloc[:,1:7] = df_PSP_Storage.iloc[:,1:7].divide(1000)
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(x = "Week", y = "Stored Energy Value 2015 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "blue",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2016 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "red",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2017 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "orange",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2018 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "green",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2019 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "purple",alpha=0.3)

df_PSP_Storage["Average"] = df_PSP_Storage.iloc[:,1:7].mean(axis = 1)
sns.lineplot(x = "Week", y = "Average" ,data = df_PSP_Storage, ax = ax
                    , color = "black")
ax.set_title("Speicherfüllstand der Speicherkraftwerke");
ax.legend(loc = "upper left", labels = ["2015","2016","2017","2018","2019","Durchschnitt"])

ax.set_ylabel("Speicherfüllstand [MWh]")

plt.savefig("../Bilder/Frage/Speicherfüllstand historisch", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax2 = ax.twiny()

df_ToPlot = pd.DataFrame()
df_ToPlot["Original"] = df_PSP_Storage["Stored Energy Value 2018 [MWh] - Austria (AT)"] / 1000

sns.lineplot(x = np.linspace(0,52,53),y = "Original",data = df_ToPlot, ax = ax2
                    , color = "black", legend = False)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax2.set_xticklabels("")
df_ToPlot = pd.DataFrame()
df_ToPlot["PSP_UBA"] = df_UBA_2030_Alte["var_storage_PSP"] / 1000
df_ToPlot["PSP_GPC"] = df_GPC_2030_Alte["var_storage_PSP"] / 1000
df_ToPlot["PSP_IGW"] = df_IGW_2030_Alte["var_storage_PSP"] / 1000
sns.lineplot( x = np.linspace(0,8759,8760),y = "PSP_UBA",data = df_ToPlot, ax = ax
                    , color = "red", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "PSP_GPC",data = df_ToPlot, ax = ax
                    , color = "blue", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "PSP_IGW",data = df_ToPlot, ax = ax
                    , color = "green", legend = False)



li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
li_Month_ticks = [0,744,1416,2160,2880,3624,4344,5088,5832,6552,7296,8016]
ax.set_xlabel("")
ax.set_xticks(li_Month_ticks)
ax.set_xticklabels(li_Months, fontsize = 14)



ax.set_ylabel("Speicherfüllstand [GWh]", fontsize = 14)
ax.set_title("Füllstand der Speicherseen", fontsize = 20)
#create a legend for the whole figure
leg = fig.legend(labels = ["UBA","GPC","IGW","Original (2018)"], loc = "upper left" ,
                bbox_to_anchor = [0.1, 0.92] ,  prop={'size': 14},facecolor='#f5f5f5', framealpha=1)
#change width of legend color lines
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
ax.set_ylim(0,2200)
ax.yaxis.grid(True)
plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Speicherfüllstand PSP", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(10,6))

df_ToPlot = pd.DataFrame()
df_ToPlot["H2_UBA"] = df_UBA_2030_Alte["var_storage_H2"] / 1000
df_ToPlot["H2_GPC"] = df_GPC_2030_Alte["var_storage_H2"] / 1000
df_ToPlot["H2_IGW"] = df_IGW_2030_Alte["var_storage_H2"] / 1000
sns.lineplot( x = np.linspace(0,8759,8760),y = "H2_UBA",data = df_ToPlot, ax = ax
                    , color = "red", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "H2_GPC",data = df_ToPlot, ax = ax
                    , color = "blue", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "H2_IGW",data = df_ToPlot, ax = ax
                    , color = "green", legend = False)





li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
li_Month_ticks = [0,744,1416,2160,2880,3624,4344,5088,5832,6552,7296,8016]
ax.set_xlabel("")
ax.set_xticks(li_Month_ticks)
ax.set_xticklabels(li_Months, fontsize = 14)

ax.set_ylabel("Speicherfüllstand [GWh]", fontsize = 14)
ax.set_title("Füllstand der Speicherseen", fontsize = 20)
#create a legend for the whole figure
leg = fig.legend(labels = ["UBA","GPC","IGW"], loc = "upper left" ,
                bbox_to_anchor = [0.1, 0.92],  prop={'size': 14},facecolor='#f5f5f5', framealpha=1)
#change width of legend color lines
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
#ax.set_ylim(0,2200)
ax.yaxis.grid(True)
plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Speicherfüllstand Methan", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # Vergelich CO2 Emissioenen

# %%
li_To_Plot = ["Biomasse_CO2_Sum","Hydro_CO2_Sum","Solar_CO2_Sum","Wind_CO2_Sum",
              "Geot_CO2_Sum","Gas_CO2_Sum","PSP_CO2_Sum","H2_CO2_Sum","Import_CO2_Sum"]
li_labels = ["Biomasse","Wasserkraft","Photovoltaik","Windkraft","Geothermie","Gas","Wasserspeicher","Methanspeicher","Import"]
fig, ax = plt.subplots(figsize=(4,7))
colors_UBA = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_GPC = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_IGW = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
df_To_Plot = pd.DataFrame()

df_To_Plot2 = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_UBA_2030_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
df_To_Plot.insert(0,"index",0)
    
df_To_Plot[li_To_Plot].plot(kind = "bar", stacked = True, ax = ax,legend = False,position = 6,width=0.05, color = colors_UBA )

df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_GPC_2030_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
    

df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False, position=0,width=0.05, color = colors_GPC)


df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_IGW_2030_Alte[li_To_Plot[i]].sum() / 1e6)

 
df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False,position=3,width=0.05, color = colors_IGW)
ax.set_ylabel("CO$_2$ [t]", fontsize = 14)
ax.set_ylim(0,1e7)
leg = fig.legend(loc="upper center", bbox_to_anchor=(1.25,0.887), labels = li_labels, ncol = 1
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
plt.figtext(0.43,0.305, "UBA",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.6,0.625, "IGW",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.775,0.36, "GPC",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
fig.suptitle('Produzierte CO$_2$ Emissionen der Szenarien\naufgeteilt auf Energieträger', fontsize=20, x = 0.8)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))
plt.tick_params(axis='x', which='both',bottom=False,top=False, labelbottom=False) 
pos = ax.get_position()
pos.y1 = 0.97   #height
ax.set_position(pos)
plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/Produzierte CO2 Emissionen", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["green","blue","red"]



li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]
df_To_Plot = pd.DataFrame()
df_To_Plot["UBA_2030_CO2"] = df_UBA_2030_Alte["CO2_Intensity"]
df_To_Plot["GPC_2030_CO2"] = df_GPC_2030_Alte["CO2_Intensity"]
df_To_Plot["IGW_2030_CO2"] = df_IGW_2030_Alte["CO2_Intensity"]



df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);

leg = ax[0].legend( labels = li_Legend, ncol = 5, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
ax[0].yaxis.grid(True)



li_Color = ["green","blue","red"]

li_Legend = ["Szenario UBA_2030","Szenario GPC_2030","Szenario IGW_2030"]

df_To_Plot = pd.DataFrame()

df_To_Plot["UBA_Mean_CO2"] = pd.Series(df_UBA_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["GPC_Mean_CO2"] = pd.Series(df_GPC_2030_Alte["CO2_Intensity"].mean())
df_To_Plot["IGW_Mean_CO2"] = pd.Series(df_IGW_2030_Alte["CO2_Intensity"].mean())

df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])

fig.suptitle("Vergleich der CO$_2$ Emissionen der 2030 Varianten", fontsize=20)



pos = ax[0].get_position()
pos.y1 = 0.95   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2030/Vergleich/CO2_Emissionen", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# # Vergleich 2050

# %% [markdown]
# ## Vergelich REslat zwischen Var

# %%
fig, ax = plt.subplots(figsize=(12, 5))
li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
df_UBA_2050_Bericht["Residuallast"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "red" )
#df_UBA_2050_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="red", marker='.', alpha=0.08, linestyle='None', legend=False)


df_GPC_2050_Bericht["Residuallast"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "blue" )
#df_GPC_2050_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="blue", marker='.', alpha=0.08, linestyle='None', legend=False)

df_FHT_2050_Bericht["Residuallast"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "green" )
#df_FHT_2050_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="green", marker='.', alpha=0.08, linestyle='None', legend=False)

ax.set_xlabel("")
ax.set_ylabel("Residuallast [MW]", fontsize = 13)
ax.set_title("Residuallast der Szenarien für 2050 ohne reaktive Energieträger", fontsize = 20)
ax.set_xticklabels(li_Months)
plt.setp(ax.get_xticklabels(), fontsize=13)
plt.setp(ax.get_yticklabels(), fontsize=13)


leg = fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.91), labels = ["UBA","GPC","FHT"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

ax.yaxis.grid(True)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))

plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Residuallast_2050", bbox_inches = 'tight',pad_inches = 0.08)

# %%
  
    
fig, ax = plt.subplots(figsize=(6,4))

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_UBA"] = df_UBA_2050_Bericht["Residuallast"].sort_values(ascending = False)




sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_UBA",ax = ax, color = "red")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_GPC"] = df_GPC_2050_Bericht["Residuallast"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_GPC",ax = ax, color = "blue")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_FHT"] = df_FHT_2050_Bericht["Residuallast"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_FHT",ax = ax, color = "green")



ax.set_title("Leistungskennlinie der Residuallast\nohne reaktive Energieträger",fontsize = 16)
ax.set_xlabel("Stunde", fontsize = 14)
ax.set_ylabel("Leistung [MW]", fontsize = 14)
ax.yaxis.grid(True)

leg = fig.legend(loc="upper center", bbox_to_anchor=(0.6,0.835), labels = ["UBA","GPC","FHT"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Residuallast_Leistungskennlinie_2050", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(12, 5))
li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
df_UBA_2050_Alte["Residuallast_H2"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "red" )
#df_UBA_2050_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="red", marker='.', alpha=0.08, linestyle='None', legend=False)


df_GPC_2050_Alte["Residuallast_H2"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "blue" )
#df_GPC_2050_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="blue", marker='.', alpha=0.08, linestyle='None', legend=False)

df_FHT_2050_Alte["Residuallast_H2"].resample("D").mean().plot(x = np.linspace(0,8759,8760),kind = "line" ,ax = ax, color = "green" )
#df_FHT_2050_Bericht["Residuallast"].plot(x = np.linspace(0,8759,8760),ax=ax, color="green", marker='.', alpha=0.08, linestyle='None', legend=False)

ax.set_xlabel("")
ax.set_ylabel("Residuallast [MW]", fontsize = 13)
ax.set_title("Residuallast der Szenarien für 2050 mit Wasser- und Methanspeicher", fontsize = 20)
ax.set_xticklabels(li_Months)
plt.setp(ax.get_xticklabels(), fontsize=13)
plt.setp(ax.get_yticklabels(), fontsize=13)
ax.set_ylim(-11000,2000)

leg = fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.91), labels = ["UBA","GPC","FHT"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

ax.yaxis.grid(True)

ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Residuallast_2050_mit_reaktiv", bbox_inches = 'tight',pad_inches = 0.08)

# %%
  
    
fig, ax = plt.subplots(figsize=(6,5))

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_H2_UBA"] = df_UBA_2050_Alte["Residuallast_H2"].sort_values(ascending = False)




sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_H2_UBA",ax = ax, color = "red")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_H2_GPC"] = df_GPC_2050_Alte["Residuallast_H2"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_H2_GPC",ax = ax, color = "blue")

df_ToPlot = pd.DataFrame()
df_ToPlot["Residuallast_H2_FHT"] = df_FHT_2050_Alte["Residuallast_H2"].sort_values(ascending = False)
sns.lineplot( data = df_ToPlot,x = np.linspace(1,8760,8760)
         , y = "Residuallast_H2_FHT",ax = ax, color = "green")



ax.set_title("Leistungskennlinie der Residuallast\nmit Speicher",fontsize = 16, y = 1.13)
ax.set_xlabel("Stunde", fontsize = 14)
ax.set_ylabel("Leistung [MW]", fontsize = 14)
ax.yaxis.grid(True)
ax.set_ylim(-25000,2000)
leg = fig.legend(loc="upper center", bbox_to_anchor=(0.6,0.805), labels = ["UBA","GPC","FHT"], ncol = 3
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))
pos = ax.get_position()
pos.y1 = 0.93   #height
ax.set_position(pos)
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Residuallast_Leistungskennlinie_mit_reaktiv", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Strommix

# %%
li_To_Plot = ["Biomasse","Hydro","Solar","Wind","Geot","Gas","PSP","H2","Import"]
li_labels = ["Biomasse","Wasserkraft","Photovoltaik","Windkraft","Geothermie","Gas","Wasserspeicher","Methanspeicher","Import"]
fig, ax = plt.subplots(figsize=(4,7))
colors_UBA = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_GPC = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_FHT = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
df_To_Plot = pd.DataFrame()

df_To_Plot2 = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_UBA_2050_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
df_To_Plot.insert(0,"index",0)
    
df_To_Plot[li_To_Plot].plot(kind = "bar", stacked = True, ax = ax,legend = False,position = 6,width=0.05, color = colors_UBA )

df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_GPC_2050_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
    

df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False, position=0,width=0.05, color = colors_GPC)


df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_FHT_2050_Alte[li_To_Plot[i]].sum() / 1e6)

 
df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False,position=3,width=0.05, color = colors_FHT)
ax.set_ylabel("Energie [TWh]")
ax.set_ylim(0,140)
leg = fig.legend(loc="upper center", bbox_to_anchor=(1.25,0.898), labels = li_labels, ncol = 1
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
plt.figtext(0.306,0.65, "UBA",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.524,0.838, "FHT",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.74,0.712, "GPC",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
fig.suptitle('Produzierte Energie der Szenarien\naufgeteilt auf Energieträger', fontsize=20, x = 0.8)

plt.tick_params(axis='x', which='both',bottom=False,top=False, labelbottom=False) 
pos = ax.get_position()
pos.y1 = 0.96   #height
ax.set_position(pos)
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Produzierte Energie", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Vergleich Speicherbewirtschaftung

# %%
df_PSP_Storage = pd.read_csv("../Data/Water Reservoirs and Hydro Storage Plants_201812310000-201912300000.csv"
                     ,delimiter = ',')
df_PSP_Storage.iloc[:,1:6] = df_PSP_Storage.iloc[:,1:6].divide(1000)
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(x = "Week", y = "Stored Energy Value 2015 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "blue",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2016 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "red",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2017 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "orange",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2018 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "green",alpha=0.3)
sns.lineplot(x = "Week", y = "Stored Energy Value 2019 [MWh] - Austria (AT)" ,data = df_PSP_Storage, ax = ax
                    , color = "purple",alpha=0.3)

df_PSP_Storage["Average"] = df_PSP_Storage.iloc[:,1:7].mean(axis = 1)
sns.lineplot(x = "Week", y = "Average" ,data = df_PSP_Storage, ax = ax
                    , color = "black")
ax.set_title("Speicherfüllstand der Speicherkraftwerke", fontsize = 20);
ax.legend(loc = "upper left", labels = ["2015","2016","2017","2018","2019","Durchschnitt"])


var_mon = len(df_PSP_Storage) / 12
li_tick_mon = []

for i in range(0,12,1):
    li_tick_mon.append(i * var_mon)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))
ax.set_xticks(li_tick_mon)
ax.set_xticklabels(["Jan","Feb","Mär","Apr","Mai","Jun","Jul",
                       "Aug","Sep","Okt","Nov","Dez"], fontsize = 14)
ax.set_ylabel("Speicherfüllstand [GWh]", fontsize = 14)

plt.savefig("../Bilder/Frage/Speicherfüllstand historisch", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax2 = ax.twiny()

df_ToPlot = pd.DataFrame()
df_ToPlot["Original"] = df_PSP_Storage["Stored Energy Value 2018 [MWh] - Austria (AT)"] / 1000

sns.lineplot(x = np.linspace(0,52,53),y = "Original",data = df_ToPlot, ax = ax2
                    , color = "black", legend = False)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax2.set_xticklabels("")
df_ToPlot = pd.DataFrame()
df_ToPlot["PSP_UBA"] = df_UBA_2050_Alte["var_storage_PSP"] / 1000
df_ToPlot["PSP_GPC"] = df_GPC_2050_Alte["var_storage_PSP"] / 1000
df_ToPlot["PSP_FHT"] = df_FHT_2050_Alte["var_storage_PSP"] / 1000
sns.lineplot( x = np.linspace(0,8759,8760),y = "PSP_UBA",data = df_ToPlot, ax = ax
                    , color = "red", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "PSP_GPC",data = df_ToPlot, ax = ax
                    , color = "blue", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "PSP_FHT",data = df_ToPlot, ax = ax
                    , color = "green", legend = False)



li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
li_Month_ticks = [0,744,1416,2160,2880,3624,4344,5088,5832,6552,7296,8016]
ax.set_xlabel("")
ax.set_xticks(li_Month_ticks)
ax.set_xticklabels(li_Months, fontsize = 14)



ax.set_ylabel("Speicherfüllstand [GWh]", fontsize = 14)
ax.set_title("Füllstand der Speicherseen", fontsize = 20)
#create a legend for the whole figure
leg = fig.legend(labels = ["UBA","GPC","FHT","Original (2018)"], loc = "upper left" ,
                bbox_to_anchor = [0.1, 0.92] ,  prop={'size': 14},facecolor='#f5f5f5', framealpha=1)
#change width of legend color lines
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
ax.set_ylim(0,2200)
ax.yaxis.grid(True)
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Speicherfüllstand PSP", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(10,6))

df_ToPlot = pd.DataFrame()
df_ToPlot["H2_UBA"] = df_UBA_2050_Alte["var_storage_H2"] / 1000
df_ToPlot["H2_GPC"] = df_GPC_2050_Alte["var_storage_H2"] / 1000
df_ToPlot["H2_FHT"] = df_FHT_2050_Alte["var_storage_H2"] / 1000
sns.lineplot( x = np.linspace(0,8759,8760),y = "H2_UBA",data = df_ToPlot, ax = ax
                    , color = "red", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "H2_GPC",data = df_ToPlot, ax = ax
                    , color = "blue", legend = False)
sns.lineplot( x = np.linspace(0,8759,8760),y = "H2_FHT",data = df_ToPlot, ax = ax
                    , color = "green", legend = False)





li_Months = ["Jan","Feb","Mrz","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"]
li_Month_ticks = [0,744,1416,2160,2880,3624,4344,5088,5832,6552,7296,8016]
ax.set_xlabel("")
ax.set_xticks(li_Month_ticks)
ax.set_xticklabels(li_Months, fontsize = 14)

ax.set_ylabel("Speicherfüllstand [GWh]", fontsize = 14)
ax.set_title("Füllstand der Speicherseen", fontsize = 20)
#create a legend for the whole figure
leg = fig.legend(labels = ["UBA","GPC","FHT"], loc = "upper left" ,
                bbox_to_anchor = [0.1, 0.92],  prop={'size': 14},facecolor='#f5f5f5', framealpha=1)
#change width of legend color lines
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
#ax.set_ylim(0,2200)
ax.yaxis.grid(True)
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Speicherfüllstand Methan", bbox_inches = 'tight',pad_inches = 0.08)

# %% [markdown]
# ## Vergelich CO2 Emissioenen

# %%
li_To_Plot = ["Biomasse_CO2_Sum","Hydro_CO2_Sum","Solar_CO2_Sum","Wind_CO2_Sum",
              "Geot_CO2_Sum","Gas_CO2_Sum","PSP_CO2_Sum","H2_CO2_Sum","Import_CO2_Sum"]
li_labels = ["Biomasse","Wasserkraft","Photovoltaik","Windkraft","Geothermie","Gas","Wasserspeicher","Methanspeicher","Import"]
fig, ax = plt.subplots(figsize=(4,7))
colors_UBA = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_GPC = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
colors_FHT = ["green", "#0088ff","orange", "cyan","grey", "purple", "#0000ff","pink", "red","black"]
df_To_Plot = pd.DataFrame()

df_To_Plot2 = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_UBA_2050_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
df_To_Plot.insert(0,"index",0)
    
df_To_Plot[li_To_Plot].plot(kind = "bar", stacked = True, ax = ax,legend = False,position = 6,width=0.05, color = colors_UBA )

df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_GPC_2050_Alte[li_To_Plot[i]].sum() / 1e6)

    
    
    

df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False, position=0,width=0.05, color = colors_GPC)


df_To_Plot = pd.DataFrame()
for i in range(0,len(li_To_Plot),1):
    df_To_Plot[li_To_Plot[i]] = pd.Series(df_FHT_2050_Alte[li_To_Plot[i]].sum() / 1e6)

 
df_To_Plot.plot(kind = "bar", stacked = True, ax = ax,legend = False,position=3,width=0.05, color = colors_FHT)
ax.set_ylabel("CO$_2$ [t]", fontsize = 14)
ax.set_ylim(0,5e6)
leg = fig.legend(loc="upper center", bbox_to_anchor=(1.25,0.887), labels = li_labels, ncol = 1
                 ,fontsize = 14,facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
plt.figtext(0.41,0.587, "UBA",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.593,0.725, "FHT",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
plt.figtext(0.77,0.655, "GPC",fontsize = 12 , bbox=dict(fill=False, edgecolor='black', linewidth=1))
fig.suptitle('Produzierte CO$_2$ Emissionen der Szenarien\naufgeteilt auf Energieträger', fontsize=20, x = 0.8)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format_string('%d', x, 1)))
plt.tick_params(axis='x', which='both',bottom=False,top=False, labelbottom=False) 
pos = ax.get_position()
pos.y1 = 0.97   #height
ax.set_position(pos)
plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/Produzierte CO2 Emissionen", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 5),gridspec_kw={'width_ratios': [4, 1]})

li_Color = ["green","blue","red"]



li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario FHT_2050"]
df_To_Plot = pd.DataFrame()
df_To_Plot["UBA_2050_CO2"] = df_UBA_2050_Alte["CO2_Intensity"]
df_To_Plot["GPC_2050_CO2"] = df_GPC_2050_Alte["CO2_Intensity"]
df_To_Plot["FHT_2050_CO2"] = df_FHT_2050_Alte["CO2_Intensity"]



df_To_Plot.resample("W").mean().plot(kind = "line", ax = ax[0], color = li_Color)

ax[0].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);

leg = ax[0].legend( labels = li_Legend, ncol = 5, loc = "upper center",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
ax[0].yaxis.grid(True)
ax[0].set_ylim(0,60)


li_Color = ["green","blue","red"]

li_Legend = ["Szenario UBA_2050","Szenario GPC_2050","Szenario FHT_2050"]

df_To_Plot = pd.DataFrame()

df_To_Plot["UBA_Mean_CO2"] = pd.Series(df_UBA_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["GPC_Mean_CO2"] = pd.Series(df_GPC_2050_Alte["CO2_Intensity"].mean())
df_To_Plot["FHT_Mean_CO2"] = pd.Series(df_FHT_2050_Alte["CO2_Intensity"].mean())

df_To_Plot.plot(kind = "bar", ax = ax[1], color = li_Color, zorder = 3, legend = False)

ax[1].set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax[1].tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax[1].yaxis.grid(True)
ax[1].set_xticklabels([""])

fig.suptitle("Vergleich der CO$_2$ Emissionen der 2050 Varianten", fontsize=20)



pos = ax[0].get_position()
pos.y1 = 0.95   #height
ax[0].set_position(pos) 



plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/CO2_Emissionen", bbox_inches = 'tight',pad_inches = 0.08)

# %%
fig, ax = plt.subplots(figsize=(12, 5))

ax2 = ax.twinx()



df_To_Plot = pd.DataFrame()

df_FHT_2050_Alte["CO2_Intensity"].resample("W").mean().plot(kind = "line", ax = ax, color = "red")
df_FHT_2050_Alte["Wind"].resample("W").mean().plot(kind = "line", ax = ax2, color = "cyan")

ax.set_ylabel("CO$_2$ Intensität [gCO$_2$eq/kWh]", fontsize = 14);
ax2.set_ylabel("Leistung [MW]", fontsize = 14);
ax.set_title("Korrelation der CO$_2$ Emissionen mit Windkraft", fontsize = 20);

leg = ax.legend( labels = ["Emissionen"], loc = "upper left",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1)
leg2 = ax2.legend( labels = ["Windkraft"], ncol = 5, loc = "upper right",handlelength = 2,
               facecolor='#f5f5f5', framealpha=1, bbox_to_anchor=(0.93,1))
ax.yaxis.grid(True)

plt.tight_layout()
plt.savefig("../Bilder/2050/Vergleich/CO2_Emissionen_Korr", bbox_inches = 'tight',pad_inches = 0.08)
